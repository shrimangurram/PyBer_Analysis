# %%
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt
import statistics
import numpy as np
from matplotlib.ticker import MultipleLocator
import os
import pandas as pd

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x215973446c8>,
#   <matplotlib.patches.Wedge at 0x21597344e88>,
#   <matplotlib.patches.Wedge at 0x2159734ad08>,
#   <matplotlib.patches.Wedge at 0x21597350c08>,
#   <matplotlib.patches.Wedge at 0x21597356f48>,
#   <matplotlib.patches.Wedge at 0x2159735df48>,
#   <matplotlib.patches.Wedge at 0x2159731d588>,
#   <matplotlib.patches.Wedge at 0x2159736a9c8>,
#   <matplotlib.patches.Wedge at 0x21597370908>,
#   <matplotlib.patches.Wedge at 0x2159735db48>,
#   <matplotlib.patches.Wedge at 0x2159737d688>,
#   <matplotlib.patches.Wedge at 0x215973815c8>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.5, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()

# %%
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()

# %%
# Files to load
city_data_to_load = os.path.join("Resources", "city_data.csv")
ride_data_to_load = os.path.join("Resources", "ride_data.csv")

# %%
# Read the city data file and store it in a pandas DataFrame.
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
# Read the ride data file and store it in a pandas DataFrame.
ride_data_df = pd.read_csv(ride_data_to_load)
ride_data_df.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the DataFrame
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
pyber_data_df.columns = ['City', 'Date', 'Fare','Ride Id', 'No. Drivers', 'City Type'] 
pyber_data_df.head()
# Out:
#                  City                 Date   Fare        Ride Id  No. Drivers  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873            5
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577           72
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003           57
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178           34
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344           46
#
#   City Type
# 0     Urban
# 1     Urban
# 2     Urban
# 3     Urban
# 4     Urban

# %%
pyber_data_df.set_index("Date")
# Out:
#                                    City   Fare        Ride Id  No. Drivers  \
# Date
# 2019-01-14 10:14:22  Lake Jonathanshire  13.83  5739410935873            5
# 2019-03-04 18:24:09  South Michelleport  30.24  2343912425577           72
# 2019-02-24 04:29:00  Port Samanthamouth  33.44  2005065760003           57
# 2019-02-10 23:22:03          Rodneyfort  23.44  5149245426178           34
# 2019-03-06 04:28:35          South Jack  34.58  3908451377344           46
# ...                                 ...    ...            ...          ...
# 2019-04-29 17:04:39         Michaelberg  13.38  8550365057598            6
# 2019-01-30 00:05:47     Lake Latoyabury  20.76  9018727594352            2
# 2019-02-10 21:03:50         North Jaime  11.11  2781339863778            1
# 2019-05-07 19:22:15        West Heather  44.94  4256853490277            4
# 2019-04-25 10:20:13          Newtonview  55.84  9990581345298            1
#
#                     City Type
# Date
# 2019-01-14 10:14:22     Urban
# 2019-03-04 18:24:09     Urban
# 2019-02-24 04:29:00     Urban
# 2019-02-10 23:22:03     Urban
# 2019-03-06 04:28:35     Urban
# ...                       ...
# 2019-04-29 17:04:39     Rural
# 2019-01-30 00:05:47     Rural
# 2019-02-10 21:03:50     Rural
# 2019-05-07 19:22:15     Rural
# 2019-04-25 10:20:13     Rural
#
# [2375 rows x 5 columns]

# %%
fares_data_df = pyber_data_df[['Date', 'City Type', 'Fare']].copy()
fares_data_df
# Out:
#                      Date City Type   Fare
# 0     2019-01-14 10:14:22     Urban  13.83
# 1     2019-03-04 18:24:09     Urban  30.24
# 2     2019-02-24 04:29:00     Urban  33.44
# 3     2019-02-10 23:22:03     Urban  23.44
# 4     2019-03-06 04:28:35     Urban  34.58
# ...                   ...       ...    ...
# 2370  2019-04-29 17:04:39     Rural  13.38
# 2371  2019-01-30 00:05:47     Rural  20.76
# 2372  2019-02-10 21:03:50     Rural  11.11
# 2373  2019-05-07 19:22:15     Rural  44.94
# 2374  2019-04-25 10:20:13     Rural  55.84
#
# [2375 rows x 3 columns]

# %%
fares_data_df.set_index("Date")
# Out:
#                     City Type   Fare
# Date
# 2019-01-14 10:14:22     Urban  13.83
# 2019-03-04 18:24:09     Urban  30.24
# 2019-02-24 04:29:00     Urban  33.44
# 2019-02-10 23:22:03     Urban  23.44
# 2019-03-06 04:28:35     Urban  34.58
# ...                       ...    ...
# 2019-04-29 17:04:39     Rural  13.38
# 2019-01-30 00:05:47     Rural  20.76
# 2019-02-10 21:03:50     Rural  11.11
# 2019-05-07 19:22:15     Rural  44.94
# 2019-04-25 10:20:13     Rural  55.84
#
# [2375 rows x 2 columns]

# %%
fares_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2375 entries, 0 to 2374
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2375 non-null   object
#  1   City Type  2375 non-null   object
#  2   Fare       2375 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 74.2+ KB

# %%
fares_data_df['Date'] =  pd.to_datetime(fares_data_df['Date'], infer_datetime_format=True)

# %%
fares_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2375 entries, 0 to 2374
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2375 non-null   datetime64[ns]
#  1   City Type  2375 non-null   object
#  2   Fare       2375 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 74.2+ KB

# %%
fares_data_df
# Out:
#                     Date City Type   Fare
# 0    2019-01-14 10:14:22     Urban  13.83
# 1    2019-03-04 18:24:09     Urban  30.24
# 2    2019-02-24 04:29:00     Urban  33.44
# 3    2019-02-10 23:22:03     Urban  23.44
# 4    2019-03-06 04:28:35     Urban  34.58
# ...                  ...       ...    ...
# 2370 2019-04-29 17:04:39     Rural  13.38
# 2371 2019-01-30 00:05:47     Rural  20.76
# 2372 2019-02-10 21:03:50     Rural  11.11
# 2373 2019-05-07 19:22:15     Rural  44.94
# 2374 2019-04-25 10:20:13     Rural  55.84
#
# [2375 rows x 3 columns]

# %%
fares_sum_df = fares_data_df.groupby(["City Type", "Date"]).sum()["Fare"]
fares_sum_df
# Out:
# City Type  Date
# Rural      2019-01-01 09:45:36    43.69
#            2019-01-02 11:18:32    52.12
#            2019-01-03 19:51:01    19.90
#            2019-01-04 03:31:26    24.88
#            2019-01-06 07:38:40    47.33
#                                   ...
# Urban      2019-05-08 04:20:00    21.99
#            2019-05-08 04:39:49    18.45
#            2019-05-08 07:29:01    18.55
#            2019-05-08 11:38:35    19.77
#            2019-05-08 13:10:18    18.04
# Name: Fare, Length: 2375, dtype: float64

# %%
fares_sum_df.dtypes
# Out:
# dtype('float64')

# %%
fares_sum_df.to_frame()
# Out:
#                                 Fare
# City Type Date
# Rural     2019-01-01 09:45:36  43.69
#           2019-01-02 11:18:32  52.12
#           2019-01-03 19:51:01  19.90
#           2019-01-04 03:31:26  24.88
#           2019-01-06 07:38:40  47.33
# ...                              ...
# Urban     2019-05-08 04:20:00  21.99
#           2019-05-08 04:39:49  18.45
#           2019-05-08 07:29:01  18.55
#           2019-05-08 11:38:35  19.77
#           2019-05-08 13:10:18  18.04
#
# [2375 rows x 1 columns]

# %%
fares_sum_df = fares_sum_df.to_frame()

# %%
fares_sum_df
# Out:
#                                 Fare
# City Type Date
# Rural     2019-01-01 09:45:36  43.69
#           2019-01-02 11:18:32  52.12
#           2019-01-03 19:51:01  19.90
#           2019-01-04 03:31:26  24.88
#           2019-01-06 07:38:40  47.33
# ...                              ...
# Urban     2019-05-08 04:20:00  21.99
#           2019-05-08 04:39:49  18.45
#           2019-05-08 07:29:01  18.55
#           2019-05-08 11:38:35  19.77
#           2019-05-08 13:10:18  18.04
#
# [2375 rows x 1 columns]

# %%
fares_sum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2375 entries, ('Rural', Timestamp('2019-01-01 09:45:36')) to ('Urban', Timestamp('2019-05-08 13:10:18'))
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fare    2375 non-null   float64
# dtypes: float64(1)
# memory usage: 44.2+ KB

# %%
fares_sum_df1 = fares_sum_df.copy()

# %%
fares_sum_df1
# Out:
#                                 Fare
# City Type Date
# Rural     2019-01-01 09:45:36  43.69
#           2019-01-02 11:18:32  52.12
#           2019-01-03 19:51:01  19.90
#           2019-01-04 03:31:26  24.88
#           2019-01-06 07:38:40  47.33
# ...                              ...
# Urban     2019-05-08 04:20:00  21.99
#           2019-05-08 04:39:49  18.45
#           2019-05-08 07:29:01  18.55
#           2019-05-08 11:38:35  19.77
#           2019-05-08 13:10:18  18.04
#
# [2375 rows x 1 columns]

# %%
fares_sum_df1.reset_index()
# Out:
#      City Type                Date   Fare
# 0        Rural 2019-01-01 09:45:36  43.69
# 1        Rural 2019-01-02 11:18:32  52.12
# 2        Rural 2019-01-03 19:51:01  19.90
# 3        Rural 2019-01-04 03:31:26  24.88
# 4        Rural 2019-01-06 07:38:40  47.33
# ...        ...                 ...    ...
# 2370     Urban 2019-05-08 04:20:00  21.99
# 2371     Urban 2019-05-08 04:39:49  18.45
# 2372     Urban 2019-05-08 07:29:01  18.55
# 2373     Urban 2019-05-08 11:38:35  19.77
# 2374     Urban 2019-05-08 13:10:18  18.04
#
# [2375 rows x 3 columns]

# %%
pivot_table_df = pd.pivot_table(fares_sum_df1, values='Fare', index=['Date'],
                    columns=['City Type'])
pivot_table_df
# Out:
# City Type            Rural  Suburban  Urban
# Date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
date_range_df = pivot_table_df.loc['2019-01-01':'2019-04-28']

# %%
date_range_df
# Out:
# City Type            Rural  Suburban  Urban
# Date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
weekly_summary_df = pd.DataFrame()
weekly_summary_df['Rural'] = date_range_df.Rural.resample('W').sum()
weekly_summary_df['Suburban'] = date_range_df.Suburban.resample('W').sum()
weekly_summary_df['Urban'] = date_range_df.Urban.resample('W').sum()
weekly_summary_df
# Out:
#              Rural  Suburban    Urban
# Date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
weekly_summary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17 entries, 2019-01-06 to 2019-04-28
# Freq: W-SUN
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     17 non-null     float64
#  1   Suburban  17 non-null     float64
#  2   Urban     17 non-null     float64
# dtypes: float64(3)
# memory usage: 544.0 bytes

# %%
weekly_summary_df1 = weekly_summary_df.copy()
weekly_summary_df1
# Out:
#              Rural  Suburban    Urban
# Date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
weekly_summary_df1.reset_index(level=0,inplace=True)

# %%
weekly_summary_df1
# Out:
#          Date   Rural  Suburban    Urban
# 0  2019-01-06  187.92    721.60  1661.68
# 1  2019-01-13   67.65   1105.13  2050.43
# 2  2019-01-20  306.00   1218.20  1939.02
# 3  2019-01-27  179.69   1203.28  2129.51
# 4  2019-02-03  333.08   1042.79  2086.94
# 5  2019-02-10  115.80    974.34  2162.64
# 6  2019-02-17   95.82   1045.50  2235.07
# 7  2019-02-24  419.06   1412.74  2466.29
# 8  2019-03-03  175.14    858.46  2218.20
# 9  2019-03-10  303.94    925.27  2470.93
# 10 2019-03-17  163.39    906.20  2044.42
# 11 2019-03-24  189.76   1122.20  2368.37
# 12 2019-03-31  199.42   1045.06  1942.77
# 13 2019-04-07  501.24   1010.73  2356.70
# 14 2019-04-14  269.79    784.82  2390.72
# 15 2019-04-21  214.14   1149.27  2303.80
# 16 2019-04-28  191.85   1357.75  2238.29

# %%
weekly_summary_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      17 non-null     datetime64[ns]
#  1   Rural     17 non-null     float64
#  2   Suburban  17 non-null     float64
#  3   Urban     17 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 672.0 bytes

# %%
#weekly_summary_df1.columns = ['DATE','RURAL', 'SUBURBAN','URBAN'] 
#weekly_summary_df1

# %%
test_df = pd.DataFrame(weekly_summary_df1)
test_df
# Out:
#          Date   Rural  Suburban    Urban
# 0  2019-01-06  187.92    721.60  1661.68
# 1  2019-01-13   67.65   1105.13  2050.43
# 2  2019-01-20  306.00   1218.20  1939.02
# 3  2019-01-27  179.69   1203.28  2129.51
# 4  2019-02-03  333.08   1042.79  2086.94
# 5  2019-02-10  115.80    974.34  2162.64
# 6  2019-02-17   95.82   1045.50  2235.07
# 7  2019-02-24  419.06   1412.74  2466.29
# 8  2019-03-03  175.14    858.46  2218.20
# 9  2019-03-10  303.94    925.27  2470.93
# 10 2019-03-17  163.39    906.20  2044.42
# 11 2019-03-24  189.76   1122.20  2368.37
# 12 2019-03-31  199.42   1045.06  1942.77
# 13 2019-04-07  501.24   1010.73  2356.70
# 14 2019-04-14  269.79    784.82  2390.72
# 15 2019-04-21  214.14   1149.27  2303.80
# 16 2019-04-28  191.85   1357.75  2238.29

# %%
x_axis = test_df['Date'].tolist()
y_axis = test_df['Rural'].tolist()
#y_axis_rural = np.array(weekly_summary_df['Rural'])
#y_axis_suburban = np.array(weekly_summary_df['Suburban'])
#y_axis_urban = np.array(weekly_summary_df['Urban'])
#plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
#ax = plt.axes()
ax.plot(x_axis,y_axis)
#weekly_summary_df1.plot("Date","Rural",kind='line')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-391-336f156cacd6> in <module>
#       7 fig, ax = plt.subplots()
#       8 #ax = plt.axes()
# ----> 9 ax.plot(x_axis,y_axis)
#      10 #weekly_summary_df1.plot("Date","Rural",kind='line')
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# -> 1667             self.add_line(line)
#    1668         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1669         return lines
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1900             line.set_clip_path(self.patch)
#    1901
# -> 1902         self._update_line_limits(line)
#    1903         if not line.get_label():
#    1904             line.set_label('_line%d' % len(self.lines))
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1922         Figures out the data limit of the given line, updating self.dataLim.
#    1923         """
# -> 1924         path = line.get_path()
#    1925         if path.vertices.size == 0:
#    1926             return
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     668         if always or self._invalidx:
#     669             xconv = self.convert_xunits(self._xorig)
# --> 670             x = _to_unmasked_float_array(xconv).ravel()
#     671         else:
#     672             x = self._x
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1388         return np.ma.asarray(x, float).filled(np.nan)
#    1389     else:
# -> 1390         return np.asarray(x, float)
#    1391
#    1392
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'
